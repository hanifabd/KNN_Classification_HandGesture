# %%
import numpy as np
import skimage.io
import skimage.feature
from skimage.color import rgb2gray
from skimage.io import imread, imsave, imshow
import math
import glob
from PIL import Image
import pandas as pd
import csv

# %%
def class_definition(imgpath):
    if "sakit" in imgpath:
        return 'sakit'
    elif "sehat" in imgpath:
        return 'sehat'

# %%
def extract_feature(img):
    img_string = Image.open(img)
    img_filename = img_string.filename
    img_class = class_definition(img_filename)
#     print(img_filename)
#     print(img_class)
    
    im = skimage.io.imread(img, as_gray=True)    
    im = skimage.img_as_ubyte(im)
    im = np.true_divide(im, 32)
    im = im.astype(np.uint8)
    g = skimage.feature.greycomatrix(im, [1], [0], levels=8, symmetric=False, normed=True)
    feature = np.array([
        img_filename,
        img_class,
        skimage.feature.greycoprops(g, 'contrast')[0][0],
        skimage.feature.greycoprops(g, 'correlation')[0][0],
        skimage.feature.greycoprops(g, 'energy')[0][0],
        skimage.feature.greycoprops(g, 'homogeneity')[0][0]
    ])
    
    return feature

# %%
def training(datasets):
    feature_datasets =[]
    for data in datasets:
        data_feature = extract_feature(data)
        feature_datasets.append(data_feature)
    print(feature_datasets)
    # opening the csv file in 'w+' mode 
    file = open('training.csv', 'w+', newline ='') 
    # writing the data into the file 
    with file:     
        write = csv.writer(file) 
        write.writerows(feature_datasets)

# %%
datasets = glob.glob('lemon_dataset/training/*/*.JPG')
classifier = training(datasets)
# Out:
# [array(['lemon_dataset/training\\sakit\\0021_0001.JPG', 'sakit',
#        '0.046974287381230204', '0.9480209571000292', '0.7546575993635611',
#        '0.9765128563093849'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0002.JPG', 'sakit',
#        '0.04805105017502916', '0.9724117026572958', '0.6364813344557279',
#        '0.9759749749958326'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0003.JPG', 'sakit',
#        '0.048562385397566264', '0.9662060176902308', '0.7010779085363826',
#        '0.975718807301217'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0004.JPG', 'sakit',
#        '0.03539389898316386', '0.959685431351468', '0.8281337313681864',
#        '0.982303250541757'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0005.JPG', 'sakit',
#        '0.04480909318219703', '0.9426834747142129', '0.7790025352644601',
#        '0.9775954534089014'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0006.JPG', 'sakit',
#        '0.046315635939323224', '0.9836591421831142', '0.6731266410948492',
#        '0.9768421820303383'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit',
#        '0.0416908651441907', '0.9776536404071251', '0.6055218149811034',
#        '0.9791546174362394'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0008.JPG', 'sakit',
#        '0.04069819969994999', '0.9789247481572403', '0.6287773735517908',
#        '0.9796509001500251'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0009.JPG', 'sakit',
#        '0.03921011835305885', '0.9760235043069992', '0.6596541075677683',
#        '0.9803954409068181'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0010.JPG', 'sakit',
#        '0.03686131021836973', '0.9833012821168212', '0.6841650203809864',
#        '0.9815711775491995'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0011.JPG', 'sakit',
#        '0.03912181196866145', '0.9810389454939252', '0.6921521593543677',
#        '0.9804392440406736'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0012.JPG', 'sakit',
#        '0.04254404900816803', '0.9754524407190088', '0.7080981187836248',
#        '0.9787279754959161'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0013.JPG', 'sakit',
#        '0.0422092432072012', '0.9776304846495899', '0.6913022448387558',
#        '0.9788953783963994'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_0014.JPG', 'sakit',
#        '0.04436043507251209', '0.9698682220299364', '0.7302144946384587',
#        '0.9778198324720788'], dtype='<U42'), array(['lemon_dataset/training\\sakit\\0021_
], dtype='<U42'), array(['lemon_dataset/training\\sehat\\0010_0033.JPG', 'sehat',
#        '0.03182163693948992', '0.9860608745304638', '0.73541158431297',
#        '0.9840892315385898'], dtype='<U42'), array(['lemon_dataset/training\\sehat\\0010_0034.JPG', 'sehat',
#        '0.03921353558926488', '0.9853476779665488', '0.6246202315573244',
#        '0.9803932322053676'], dtype='<U42'), array(['lemon_dataset/training\\sehat\\0010_0035.JPG', 'sehat',
#        '0.04095811801966994', '0.9771921471205048', '0.6759106612918934',
#        '0.9795209909984998'], dtype='<U42')]

# %%
def euclidian_distance(img, data_training):
    datas_distance = []
    predict_image = extract_feature(img)
    with open(data_training) as csvfile:
        readCSV = csv.reader(csvfile, delimiter=',')
        for row in readCSV:
            img_filename = row[0]
            img_class = row[1]
            contrast_x = (float(row[2]) * float(predict_image[2])) ** 2
            correlation_x = (float(row[3]) * float(predict_image[3])) ** 2
            energy_x = (float(row[4]) * float(predict_image[4])) ** 2
            homogenity_x = (float(row[5]) * float(predict_image[5])) ** 2
            distance = contrast_x + correlation_x + energy_x + homogenity_x
            distance = math.sqrt(distance)
            
            a_data_distance = np.array([
                img_filename,
                img_class,
                distance
            ])
            
            datas_distance.append(a_data_distance)
            
    # opening the csv file in 'w+' mode 
    file = open('knn-test.csv', 'w+', newline ='') 
    # writing the data into the file 
    with file:     
        write = csv.writer(file) 
        write.writerows(datas_distance)

# %%
def classification(k,euclidian_distance):
    min_array = []
    with open(euclidian_distance) as csvfile:
        readCSV = csv.reader(csvfile, delimiter=',')
        sortedlist = sorted(readCSV, key=lambda row: row[2])
    
    data_count = 0
    while (data_count < k):
        min_array.append(sortedlist[data_count])
        data_count = data_count + 1
        
    sakit = 0
    sehat = 0
    for data in min_array:
        if data[1] == 'sakit':
            sakit = sakit + 1
        elif data[1] == 'sehat':
            sehat = sehat + 1
            
    print(sakit,sehat)
    print(*min_array, sep="\n")
    
    if (sakit > sehat):
        return 'Kategori Daun = Sakit'
    elif (sehat > sakit):
        return 'Kategori Daun = Sehat'

# %%
# Test Single
data_training = 'training1.csv'
test_image = 'lemon_dataset/test/0021_0040.JPG'
ed_result = euclidian_distance(test_image, data_training)
data_ed = 'knn-test.csv'
k = 5
class_result = classification(k, data_ed)
imshow(test_image)
print(test_image,' -> ',class_result)
# Out:
# 3 2
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.412633417374731']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.4197273323301323']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.4245379548648733']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.428268470459722']
# ['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit', '1.4328903643618625']
# lemon_dataset/test/0021_0040.JPG  ->  Kategori Daun = Sakit

# %%
# Multiple Test
data_test = glob.glob('lemon_dataset/test/*.JPG')
data_training = 'training1.csv'
data_ed = 'knn-test.csv'
k = 5
test_summary = []

for data in data_test:
    # Test Single    
    test_image = data
    ed_result = euclidian_distance(test_image, data_training)    
    class_result = classification(k, data_ed)
    test = np.array([
        test_image,
        class_result
    ])
    test_summary.append(test)

# opening the csv file in 'w+' mode 
file = open('multi_test_summary.csv', 'w+', newline ='') 
# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerows(test_summary)
# Out:
# 3 2
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.4120640027756741']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.4193197635763137']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.421484209135703']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.427234980868753']
# ['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit', '1.4316470652479316']
# 2 3
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.373913594748651']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.3803895461461508']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.3901722246919845']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.3920757734567242']
# ['lemon_dataset/training\\sehat\\0010_0011.JPG', 'sehat', '1.3923402314677504']
# 3 2
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.3961980997898473']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.4032126504860463']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.4080509138837538']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.4115740897073739']
# ['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit', '1.4161112201843469']
# 3 2
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.4033420503550806']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.4103840865209267']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.415332422138638']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.4188457805883283']
# ['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit', '1.4234268823220706']
# 2 3
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.3851213755722565']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.3916488497018087']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.4015343503018247']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.4034259046476223']
# ['lemon_dataset/training\\sehat\\0010_0011.JPG', 'sehat', '1.4037518549629422']
# 3 2
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.400238093399966']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.4072550220660955']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.41232894483961']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.415739890072408']
# ['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit', '1.4203252254623016']
# 3 2
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.412215129332306']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.419353790199983']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.423391251876217']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.4277243798532915']
# ['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit', '1.4322893460785695']
# 3 2
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.407373922144288']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.4144434190548785']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.419242745748691']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.4229253888896654']
# ['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit', '1.4275197283209697']
# 2 3
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.394696233399873']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.4015163484721638']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.4093061939804132']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.410590821091807']
# ['lemon_dataset/training\\sehat\\0010_0011.JPG', 'sehat', '1.4142718891693977']
# 3 2
# ['lemon_dataset/training\\sakit\\0021_0019.JPG', 'sakit', '1.412633417374731']
# ['lemon_dataset/training\\sehat\\0010_0022.JPG', 'sehat', '1.4197273323301323']
# ['lemon_dataset/training\\sakit\\0021_0020.JPG', 'sakit', '1.4245379548648733']
# ['lemon_dataset/training\\sehat\\0010_0012.JPG', 'sehat', '1.428268470459722']
# ['lemon_dataset/training\\sakit\\0021_0007.JPG', 'sakit', '1.4328903643618625']

# %%
# Accuracy
test_result = 'multi_test_summary.csv'
with open(test_result) as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    line = len(list(readCSV))
accuracy = 0

with open(test_result) as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        print(row)
        if '0021_' in row[0]:
            if 'Sakit' in row[1]:
                accuracy = accuracy + 1
        elif '0010_' in row[0]:
            if 'Sehat' in row[1]:
                accuracy = accuracy + 1

accuracy = (accuracy/line)*100
print('\nModel Accuracy :',accuracy,'%')
print('Data Count :',line)
# Out:
# ['lemon_dataset/test\\0010_0036.JPG', 'Kategori Daun = Sakit']
# ['lemon_dataset/test\\0010_0037.JPG', 'Kategori Daun = Sehat']
# ['lemon_dataset/test\\0010_0038.JPG', 'Kategori Daun = Sakit']
# ['lemon_dataset/test\\0010_0039.JPG', 'Kategori Daun = Sakit']
# ['lemon_dataset/test\\0010_0040.JPG', 'Kategori Daun = Sehat']
# ['lemon_dataset/test\\0021_0036.JPG', 'Kategori Daun = Sakit']
# ['lemon_dataset/test\\0021_0037.JPG', 'Kategori Daun = Sakit']
# ['lemon_dataset/test\\0021_0038.JPG', 'Kategori Daun = Sakit']
# ['lemon_dataset/test\\0021_0039.JPG', 'Kategori Daun = Sehat']
# ['lemon_dataset/test\\0021_0040.JPG', 'Kategori Daun = Sakit']
#
# Model Accuracy : 60.0 %
# Data Count : 10
